# %%
import os
import sys
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# %%
#weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
weight_decay_lambda = 0.1

# %%
network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

# %%
for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break
# Out:
# epoch:0, train acc:0.13333333333333333, test acc:0.1267
# epoch:1, train acc:0.14333333333333334, test acc:0.1311
# epoch:2, train acc:0.14, test acc:0.1335
# epoch:3, train acc:0.15666666666666668, test acc:0.1452
# epoch:4, train acc:0.18666666666666668, test acc:0.1531
# epoch:5, train acc:0.18666666666666668, test acc:0.1603
# epoch:6, train acc:0.22, test acc:0.1722
# epoch:7, train acc:0.22666666666666666, test acc:0.1841
# epoch:8, train acc:0.25, test acc:0.1948
# epoch:9, train acc:0.2633333333333333, test acc:0.206
# epoch:10, train acc:0.28, test acc:0.2117
# epoch:11, train acc:0.29, test acc:0.2222
# epoch:12, train acc:0.2833333333333333, test acc:0.2279
# epoch:13, train acc:0.30666666666666664, test acc:0.242
# epoch:14, train acc:0.32666666666666666, test acc:0.2535
# epoch:15, train acc:0.3566666666666667, test acc:0.2662
# epoch:16, train acc:0.38666666666666666, test acc:0.2795
# epoch:17, train acc:0.4066666666666667, test acc:0.2843
# epoch:18, train acc:0.39, test acc:0.2869
# epoch:19, train acc:0.41333333333333333, test acc:0.292
# epoch:20, train acc:0.42333333333333334, test acc:0.2962
# epoch:21, train acc:0.43666666666666665, test acc:0.2992
# epoch:22, train acc:0.45666666666666667, test acc:0.3141
# epoch:23, train acc:0.46, test acc:0.3145
# epoch:24, train acc:0.45666666666666667, test acc:0.318
# epoch:25, train acc:0.45666666666666667, test acc:0.3208
# epoch:26, train acc:0.48333333333333334, test acc:0.3377
# epoch:27, train acc:0.49666666666666665, test acc:0.3548
# epoch:28, train acc:0.5066666666666667, test acc:0.3573
# epoch:29, train acc:0.5233333333333333, test acc:0.361
# epoch:30, train acc:0.5333333333333333, test acc:0.3697
# epoch:31, train acc:0.5366666666666666, test acc:0.3847
# epoch:32, train acc:0.5466666666666666, test acc:0.3853
# epoch:33, train acc:0.5466666666666666, test acc:0.3808
# epoch:34, train acc:0.55, test acc:0.3898
# epoch:35, train acc:0.5533333333333333, test acc:0.3881
# epoch:36, train acc:0.5566666666666666, test acc:0.4113
# epoch:37, train acc:0.5666666666666667, test acc:0.4248
# epoch:38, train acc:0.57, test acc:0.4175
# epoch:39, train acc:0.58, test acc:0.4241
# epoch:40, train acc:0.6133333333333333, test acc:0.4317
# epoch:41, train acc:0.6166666666666667, test acc:0.4382
# epoch:42, train acc:0.6233333333333333, test acc:0.4461
# epoch:43, train acc:0.63, test acc:0.4567
# epoch:44, train acc:0.6133333333333333, test acc:0.4615
# epoch:45, train acc:0.6233333333333333, test acc:0.4641
# epoch:46, train acc:0.6566666666666666, test acc:0.4683
# epoch:47, train acc:0.6433333333333333, test acc:0.4747
# epoch:48, train acc:0.66, test acc:0.4802
# epoch:49, train acc:0.6633333333333333, test acc:0.4836
# epoch:50, train acc:0.66, test acc:0.4823
# epoch:51, train acc:0.67, test acc:0.4907
# epoch:52, train acc:0.6666666666666666, test acc:0.4958
# epoch:53, train acc:0.6833333333333333, test acc:0.5015
# epoch:54, train acc:0.6733333333333333, test acc:0.508
# epoch:55, train acc:0.7033333333333334, test acc:0.5144
# epoch:56, train acc:0.7033333333333334, test acc:0.5239
# epoch:57, train acc:0.7133333333333334, test acc:0.5335
# epoch:58, train acc:0.7133333333333334, test acc:0.532
# epoch:59, train acc:0.7133333333333334, test acc:0.5264
# epoch:60, train acc:0.7266666666666667, test acc:0.5324
# epoch:61, train acc:0.73, test acc:0.5461
# epoch:62, train acc:0.7333333333333333, test acc:0.5538
# epoch:63, train acc:0.7533333333333333, test acc:0.5765
# epoch:64, train acc:0.7666666666666667, test acc:0.591
# epoch:65, train acc:0.7566666666666667, test acc:0.5963
# epoch:66, train acc:0.7633333333333333, test acc:0.5993
# epoch:67, train acc:0.77, test acc:0.5959
# epoch:68, train acc:0.7633333333333333, test acc:0.5835
# epoch:69, train acc:0.7766666666666666, test acc:0.598
# epoch:70, train acc:0.7733333333333333, test acc:0.6007
# epoch:71, train acc:0.77, test acc:0.6066
# epoch:72, train acc:0.77, test acc:0.6058
# epoch:73, train acc:0.7633333333333333, test acc:0.5949
# epoch:74, train acc:0.78, test acc:0.607
# epoch:75, train acc:0.7833333333333333, test acc:0.6144
# epoch:76, train acc:0.7933333333333333, test acc:0.6152
# epoch:77, train acc:0.7966666666666666, test acc:0.617
# epoch:78, train acc:0.7966666666666666, test acc:0.6225
# epoch:79, train acc:0.7966666666666666, test acc:0.6343
# epoch:80, train acc:0.8033333333333333, test acc:0.6328
# epoch:81, train acc:0.8166666666666667, test acc:0.6427
# epoch:82, train acc:0.82, test acc:0.6518
# epoch:83, train acc:0.8266666666666667, test acc:0.6458
# epoch:84, train acc:0.84, test acc:0.6596
# epoch:85, train acc:0.8366666666666667, test acc:0.6596
# epoch:86, train acc:0.83, test acc:0.6632
# epoch:87, train acc:0.8266666666666667, test acc:0.6568
# epoch:88, train acc:0.83, test acc:0.6628
# epoch:89, train acc:0.8533333333333334, test acc:0.6692
# epoch:90, train acc:0.8466666666666667, test acc:0.6587
# epoch:91, train acc:0.8366666666666667, test acc:0.6562
# epoch:92, train acc:0.8333333333333334, test acc:0.6663
# epoch:93, train acc:0.84, test acc:0.6726
# epoch:94, train acc:0.83, test acc:0.664
# epoch:95, train acc:0.8466666666666667, test acc:0.6744
# epoch:96, train acc:0.85, test acc:0.6786
# epoch:97, train acc:0.86, test acc:0.6841
# epoch:98, train acc:0.8533333333333334, test acc:0.6778
# epoch:99, train acc:0.8633333333333333, test acc:0.6735
# epoch:100, train acc:0.8666666666666667, test acc:0.683
# epoch:101, train acc:0.87, test acc:0.6888
# epoch:102, train acc:0.87, test acc:0.6869
# epoch:103, train acc:0.8666666666666667, test acc:0.6837
# epoch:104, train acc:0.87, test acc:0.6855
# epoch:105, train acc:0.8666666666666667, test acc:0.6882
# epoch:106, train acc:0.87, test acc:0.683
# epoch:107, train acc:0.8566666666666667, test acc:0.6801
# epoch:108, train acc:0.8766666666666667, test acc:0.6874
# epoch:109, train acc:0.8766666666666667, test acc:0.6896
# epoch:110, train acc:0.8633333333333333, test acc:0.6912
# epoch:111, train acc:0.8733333333333333, test acc:0.6906
# epoch:112, train acc:0.8633333333333333, test acc:0.6861
# epoch:113, train acc:0.8733333333333333, test acc:0.6913
# epoch:114, train acc:0.88, test acc:0.6915
# epoch:115, train acc:0.85, test acc:0.6793
# epoch:116, train acc:0.87, test acc:0.6858
# epoch:117, train acc:0.88, test acc:0.693
# epoch:118, train acc:0.88, test acc:0.6937
# epoch:119, train acc:0.87, test acc:0.6866
# epoch:120, train acc:0.8833333333333333, test acc:0.6967
# epoch:121, train acc:0.88, test acc:0.6936
# epoch:122, train acc:0.8833333333333333, test acc:0.6989
# epoch:123, train acc:0.88, test acc:0.6949
# epoch:124, train acc:0.8833333333333333, test acc:0.691
# epoch:125, train acc:0.8733333333333333, test acc:0.6844
# epoch:126, train acc:0.8733333333333333, test acc:0.6931
# epoch:127, train acc:0.8733333333333333, test acc:0.691
# epoch:128, train acc:0.8733333333333333, test acc:0.6878
# epoch:129, train acc:0.86, test acc:0.6867
# epoch:130, train acc:0.8733333333333333, test acc:0.7001
# epoch:131, train acc:0.8833333333333333, test acc:0.7058
# epoch:132, train acc:0.8933333333333333, test acc:0.7069
# epoch:133, train acc:0.8766666666666667, test acc:0.698
# epoch:134, train acc:0.88, test acc:0.7004
# epoch:135, train acc:0.88, test acc:0.6982
# epoch:136, train acc:0.88, test acc:0.6985
# epoch:137, train acc:0.8866666666666667, test acc:0.701
# epoch:138, train acc:0.8766666666666667, test acc:0.699
# epoch:139, train acc:0.8866666666666667, test acc:0.7065
# epoch:140, train acc:0.8866666666666667, test acc:0.7096
# epoch:141, train acc:0.8933333333333333, test acc:0.7061
# epoch:142, train acc:0.8866666666666667, test acc:0.7034
# epoch:143, train acc:0.8833333333333333, test acc:0.7051
# epoch:144, train acc:0.88, test acc:0.7004
# epoch:145, train acc:0.88, test acc:0.6945
# epoch:146, train acc:0.8733333333333333, test acc:0.6962
# epoch:147, train acc:0.88, test acc:0.6982
# epoch:148, train acc:0.8833333333333333, test acc:0.706
# epoch:149, train acc:0.8866666666666667, test acc:0.7054
# epoch:150, train acc:0.8766666666666667, test acc:0.7042
# epoch:151, train acc:0.89, test acc:0.7106
# epoch:152, train acc:0.88, test acc:0.7087
# epoch:153, train acc:0.8733333333333333, test acc:0.7011
# epoch:154, train acc:0.8833333333333333, test acc:0.7075
# epoch:155, train acc:0.8766666666666667, test acc:0.6994
# epoch:156, train acc:0.8833333333333333, test acc:0.7088
# epoch:157, train acc:0.88, test acc:0.7046
# epoch:158, train acc:0.8833333333333333, test acc:0.703
# epoch:159, train acc:0.8866666666666667, test acc:0.7032
# epoch:160, train acc:0.88, test acc:0.7014
# epoch:161, train acc:0.88, test acc:0.7098
# epoch:162, train acc:0.88, test acc:0.7034
# epoch:163, train acc:0.8833333333333333, test acc:0.7048
# epoch:164, train acc:0.8933333333333333, test acc:0.7099
# epoch:165, train acc:0.8933333333333333, test acc:0.7067
# epoch:166, train acc:0.9, test acc:0.7164
# epoch:167, train acc:0.89, test acc:0.7126
# epoch:168, train acc:0.8866666666666667, test acc:0.7152
# epoch:169, train acc:0.8833333333333333, test acc:0.7001
# epoch:170, train acc:0.89, test acc:0.7064
# epoch:171, train acc:0.9, test acc:0.7175
# epoch:172, train acc:0.8933333333333333, test acc:0.7158
# epoch:173, train acc:0.8933333333333333, test acc:0.7156
# epoch:174, train acc:0.8933333333333333, test acc:0.7141
# epoch:175, train acc:0.8933333333333333, test acc:0.7121
# epoch:176, train acc:0.8833333333333333, test acc:0.708
# epoch:177, train acc:0.8933333333333333, test acc:0.7123
# epoch:178, train acc:0.8933333333333333, test acc:0.7146
# epoch:179, train acc:0.8966666666666666, test acc:0.712
# epoch:180, train acc:0.8933333333333333, test acc:0.7093
# epoch:181, train acc:0.8966666666666666, test acc:0.7136
# epoch:182, train acc:0.9033333333333333, test acc:0.7134
# epoch:183, train acc:0.8966666666666666, test acc:0.7128
# epoch:184, train acc:0.8966666666666666, test acc:0.7163
# epoch:185, train acc:0.9, test acc:0.7176
# epoch:186, train acc:0.8866666666666667, test acc:0.7085
# epoch:187, train acc:0.89, test acc:0.7106
# epoch:188, train acc:0.8966666666666666, test acc:0.7067
# epoch:189, train acc:0.8966666666666666, test acc:0.7083
# epoch:190, train acc:0.9, test acc:0.7132
# epoch:191, train acc:0.8933333333333333, test acc:0.717
# epoch:192, train acc:0.9, test acc:0.7118
# epoch:193, train acc:0.89, test acc:0.7053
# epoch:194, train acc:0.8866666666666667, test acc:0.7078
# epoch:195, train acc:0.8966666666666666, test acc:0.7062
# epoch:196, train acc:0.89, test acc:0.7074
# epoch:197, train acc:0.8966666666666666, test acc:0.7078
# epoch:198, train acc:0.8933333333333333, test acc:0.7093
# epoch:199, train acc:0.89, test acc:0.707
# epoch:200, train acc:0.9, test acc:0.7097

# %%
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
